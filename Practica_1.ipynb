# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaS94/TalentoTech-/blob/main/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practica 1 de Talento Tech: Incluye importar un dataset

# %%
#Primer paso: debo tener el archivo en una carpeta
#Segundo paso: Debo establecer una conexcion con la carpeta
#Tercer paso: Ejecutar la celda de la conexion y revisar que este ok

# %% [markdown]
# SUMA DE VARIABLES

# %%
#variable e input
val1 = 10
val2 = 12

#proceso
suma = val1 + val2

#output - salida
print(suma)
# Out:
# 22

# %% [markdown]
# # Ingreso de nuevos datos

# %%
#concetar el drive al colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#llamar la carpeta y el archivo desde su ubicacion
#siempre se necesita una variable para ejecutar una accion

Path = '/content/drive/My Drive/Colab Notebooks/DATOS/Ventas.xlsx'
#file = 'Ventas.xlsx'

# %%
#importar con pandas que es una librería de Python especializada en la manipulación y el análisis de datos.
#Ofrece estructuras de datos y operaciones para manipular tablas numéricas y series temporales
#es como el Excel de Python


import pandas as pd

# %%
#Lea el excel de la ruta que se habia guardado

df = pd.read_excel(Path)

# %%
#muestra un preview dataset

df.head(18)
# Out:
#      Region      Producto Vendedor  Ventas
# 0   Central    Accesorios    David    8287
# 1   Central    Accesorios    Karen    6909
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 4   Central      Sistemas    David   20098
# 5   Central      Sistemas    Karen   30633
# 6      Este    Accesorios      Ana    9323
# 7      Este    Accesorios    Lucas    7667
# 8      Este  Dispositivos      Ana   10348
# 9      Este  Dispositivos    Lucas    9312
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 12    Oeste    Accesorios    Kevin    4744
# 13    Oeste    Accesorios     Sara    5442
# 14    Oeste  Dispositivos    Kevin   10711
# 15    Oeste  Dispositivos     Sara    8780
# 16    Oeste      Sistemas    Kevin   32855
# 17    Oeste      Sistemas     Sara   23151
