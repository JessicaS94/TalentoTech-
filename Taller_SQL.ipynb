# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaS94/TalentoTech-/blob/main/Taller_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##TALLER SQL
#
# En este taller vamos a analizar un data set de las ligas europeas de fultbol

# %% [markdown]
# #INTRODUCCIÓN
#
# Usaré esta notebook para proporcionar una introducción a SQL, lenguaje imprescindible para todo analista de datos.
#
# Los sistemas gestores de bases de datos interpretan consultas escritas en lenguaje SQL, y así es como interactuamos y obtenemos datos de las bases de datos y aplicaciones.
#
# SQL significa Structured Query Language (Lenguaje de consulta estructurado)
# SQL permite acceder y manipular bases de datos
# SQL es una herramienta simple para el análisis avanzado de datos
# SQL no se usa sólo para manipular datos, sino también para administrar la misma base de datos, crear y modificar el diseño de objetos de la base de datos, como tablas.

# %% [markdown]
# **¿Qué es SQLite?**
#
# SQLite es una biblioteca de software que proporciona un sistema de gestión de bases de datos relacionales que se puede utilizar en casi todos los lenguajes de programación, incluido Python.
#
# El lite en SQLite significa facilidad en términos de configuración, administración de la base de datos y recursos necesarios. Las siguientes son sus características más importantes: es autónomo, sin servidor y transaccional.

# %% [markdown]
# **1. Configuraciones previas**
#
# SQLite se puede utilizar en casi todos los lenguajes de programación, incluido Python. Esta notebook corre en Python, por lo que vamos a importar la librería de SQLite y otras que nos pueden ser de utilidad más adelante.
#
# Asimismo, crearemos la conexión con la BD y listaremos las tablas con las que contamos.

# %%
#import libraries

import pandas as pd # libreria de python para manipulacion de datos
import sqlite3 # SQLite

# %%
# 1. Establecer conexión

# Los datos de entrada están disponibles en el directorio drive.

path = "/content/drive/MyDrive/Colab Notebooks/DATOS/"
database = path + 'database.sqlite' # Estoy concatenando el path con mi base de datos

# Creamos la conexión con la BD y listaremos las tablas con las que contamos

conn = sqlite3.connect(database)
print ("Conexión exitosa")
print (database)
# Out:
# Conexión exitosa
# /content/drive/MyDrive/Colab Notebooks/DATOS/database.sqlite

# %%
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %% [markdown]
# #1. Sentencia SELECT#
# **texto en negrita**
# Esta es la consulta más básica y su estructura es muy simple:
#
# Se define lo que se quiere ver después del SELECT
# Se eligen las tablas a consultar después del FROM
# Las únicas partes imprescindibles de una consulta son el SELECT y el FROM.
#
# La sintaxis de esta consulta es así:
#
# SELECT column1, column2, ...
#
# FROM table_name;
#
# Para consultar por todos los campos en una tabla sin tener que escribir uno por uno el nombre de cada campo, se utiliza SELECT *
#
# SELECT * significa que quieres obtener todas las columnas posibles de la tabla consultada. Los datos devueltos se almacenan en una tabla de resultados, denominada conjunto de resultados.
#
# La sintaxis de esta consulta es así:
#
# SELECT *
#
# FROM table_name;
#
# Es una buena práctica terminar la consulta con un punto y coma para indicar que la consulta está completa. Las palabras clave se escriben en mayúsculas y los nombres de tablas y campos se escriben en minúsculas.

# %% [markdown]
# ##Práctica 1
#
# 1**. Listar las ligas del fútbol europeo**
#
# Deben listar todas las ligas que estén en la tabla League de la base de datos de fútbol europeo.

# %%
query =""" SELECT * FROM League;"""

League = pd.read_sql(query, conn)
League
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
# Consulta de Player_attributes

query = """SELECT * FROM Player_attributes;"""

print('Atributos de los jugadores')

Player_attributes = pd.read_sql(query, conn)
Player_attributes.head(2)
# Out:
# Atributos de los jugadores
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# 0  ...    54.0       48.0     65.0             69.0            69.0
# 1  ...    54.0       48.0     65.0             69.0            69.0
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0        6.0         11.0        10.0             8.0          8.0
# 1        6.0         11.0        10.0             8.0          8.0
#
# [2 rows x 42 columns]

# %%
# Consultar los partidos de la liga de futbol europeo

query = """SELECT * FROM Match;"""

Match = pd.read_sql(query, conn)
Match
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0            492473              9987              9993               1  ...
# 1            492474             10000              9994               0  ...
# 2            492475              9984              8635               0  ...
# 3            492476              9991              9998               5  ...
# 4            492477              7947              9985               1  ...
# ...             ...               ...               ...             ...  ...
# 25974       1992091             10190             10191               1  ...
# 25975       1992092              9824             10199               1  ...
# 25976       1992093              9956             10179               2  ...
# 25977       1992094              7896             10243               0  ...
# 25978       1992095             10192              9931               4  ...
#
#         SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0      4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1      3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2      2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3      7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4      1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 25974   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25975   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25976   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25977   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25978   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [25979 rows x 115 columns]

# %%
# Consulta de paises que participan en la liga europea

query = """ SELECT *
             FROM Country; """

countries = pd.read_sql(query, conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
# Consultar los jugadores del futbol de la liga europea

query = """SELECT * FROM Player; """

Player = pd.read_sql(query, conn)
Player
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# 2      1991-05-13 00:00:00  170.18     163
# 3      1982-05-08 00:00:00  182.88     198
# 4      1979-11-08 00:00:00  182.88     154
# ...                    ...     ...     ...
# 11055  1979-04-03 00:00:00  182.88     168
# 11056  1986-12-18 00:00:00  182.88     176
# 11057  1979-04-29 00:00:00  180.34     154
# 11058  1981-10-06 00:00:00  185.42     172
# 11059  1982-06-05 00:00:00  180.34     176
#
# [11060 rows x 7 columns]

# %%
#Consultar los equipos de la Liga de futbol europea

query = """SELECT * FROM Team;"""

Team = pd.read_sql(query, conn)
Team
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
#consultar atributos de los equipos de la liga europea de futbol

query = """SELECT * FROM Team_Attributes;"""

Team_Attributes = pd.read_sql(query, conn)
Team_Attributes.head(2)
# Out:
#    id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0   1               434         9930  2010-02-22 00:00:00                60
# 1   2               434         9930  2014-09-19 00:00:00                52
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0              Balanced                   NaN                    Little
# 1              Balanced                  48.0                    Normal
#
#    buildUpPlayPassing buildUpPlayPassingClass  ... chanceCreationShooting  \
# 0                  50                   Mixed  ...                     55
# 1                  56                   Mixed  ...                     64
#
#    chanceCreationShootingClass chanceCreationPositioningClass  \
# 0                       Normal                      Organised
# 1                       Normal                      Organised
#
#    defencePressure defencePressureClass  defenceAggression  \
# 0               50               Medium                 55
# 1               47               Medium                 44
#
#   defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# 0                  Press               45                 Normal
# 1                  Press               54                 Normal
#
#   defenceDefenderLineClass
# 0                    Cover
# 1                    Cover
#
# [2 rows x 25 columns]

# %% [markdown]
# ##Práctica 1.1
#
# 1**. Listar columnas que se encuentren dentro de las categorias**

# %%
 query = """ SELECT player_name FROM Player; """

 Player = pd.read_sql(query, conn)
 Player
# Out:
#                player_name
# 0       Aaron Appindangoye
# 1          Aaron Cresswell
# 2              Aaron Doran
# 3            Aaron Galindo
# 4             Aaron Hughes
# ...                    ...
# 11055       Zoumana Camara
# 11056         Zsolt Laczko
# 11057            Zsolt Low
# 11058  Zurab Khizanishvili
# 11059   Zvjezdan Misimovic
#
# [11060 rows x 1 columns]

# %%
query ="""SELECT team_long_name FROM Team;"""

Team = pd.read_sql(query, conn)
Team
# Out:
#          team_long_name
# 0              KRC Genk
# 1          Beerschot AC
# 2      SV Zulte-Waregem
# 3      Sporting Lokeren
# 4     KSV Cercle Brugge
# ..                  ...
# 294       FC St. Gallen
# 295             FC Thun
# 296         Servette FC
# 297  FC Lausanne-Sports
# 298              Lugano
#
# [299 rows x 1 columns]

# %%
query = """ SELECT id, player_name, birthday, height, weight FROM Player;"""

Player = pd.read_sql(query, conn)
Player
# Out:
#           id          player_name             birthday  height  weight
# 0          1   Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1          2      Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# 2          3          Aaron Doran  1991-05-13 00:00:00  170.18     163
# 3          4        Aaron Galindo  1982-05-08 00:00:00  182.88     198
# 4          5         Aaron Hughes  1979-11-08 00:00:00  182.88     154
# ...      ...                  ...                  ...     ...     ...
# 11055  11071       Zoumana Camara  1979-04-03 00:00:00  182.88     168
# 11056  11072         Zsolt Laczko  1986-12-18 00:00:00  182.88     176
# 11057  11073            Zsolt Low  1979-04-29 00:00:00  180.34     154
# 11058  11074  Zurab Khizanishvili  1981-10-06 00:00:00  185.42     172
# 11059  11075   Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
#
# [11060 rows x 5 columns]

# %% [markdown]
# **Ejemplo: Listar las temporadas jugadas de esta Base de Datos**
#
# Si consultamos por todas las temporadas que se almacenaron en la tabla Matchde la base de datos de Fútbol Europeo, vamos a tener el siguiente resultado.

# %%
query = """SELECT Season FROM Match;"""

Season = pd.read_sql(query, conn)
Season
# Out:
#           season
# 0      2008/2009
# 1      2008/2009
# 2      2008/2009
# 3      2008/2009
# 4      2008/2009
# ...          ...
# 25974  2015/2016
# 25975  2015/2016
# 25976  2015/2016
# 25977  2015/2016
# 25978  2015/2016
#
# [25979 rows x 1 columns]

# %% [markdown]
# Con el resultado anterior, es muy difícil responder a la pregunta ¿Cuáles son las temporadas almacenadas en esta base de datos? Para responderla sin mucho esfuerzo, usamos SELECT DISTINCT para consultar la tabla Match de la base de datos.

# %% [markdown]
# #2. Sentencia SELECT DISTINCT
#
# La sentencia SELECT DISTINCT se utiliza para devolver sólo valores distintos (diferentes).
#
# Dentro de una tabla, una columna a menudo contiene muchos valores duplicados y a veces sólo se desea listar los diferentes valores (distintos).
#
# La sintaxis de SELECT DISTINCT es así:
#
# SELECT DISTINCT column1
#
# FROM table_name;

# %%
# Se listan las temporadas jugadas en la liga europea

query = """SELECT DISTINCT Season FROM Match;"""

Season = pd.read_sql(query, conn)
Season
# Out:
#       season
# 0  2008/2009
# 1  2009/2010
# 2  2010/2011
# 3  2011/2012
# 4  2012/2013
# 5  2013/2014
# 6  2014/2015
# 7  2015/2016

# %%
# En la tabla Player_Attributes de la base de datos de Fútbol Europeo hay el campo overall_rating que parece contener la valoración de los jugadores.
#El objetivo es ver sólo tasas diferentes de valoración general de los jugadores.

query = """SELECT DISTINCT overall_rating FROM Player_Attributes;"""

overall_rating = pd.read_sql(query, conn)
overall_rating
# Out:
#     overall_rating
# 0             67.0
# 1             62.0
# 2             61.0
# 3             74.0
# 4             73.0
# ..             ...
# 57            33.0
# 58            36.0
# 59            37.0
# 60            35.0
# 61            94.0
#
# [62 rows x 1 columns]

# %% [markdown]
# ##3. Sentencia LIMIT##
# Cuando deseamos poner un límite al resultado o no nos interesa conocer la totalidad de los resultados, podemos limitar la cantidad de registros resultantes mediante la sentencia LIMIT
#
# La sintaxis de LIMIT es así:
#
# SELECT column1, column2...
#
# FROM table_name
#
# LIMIT number;

# %% [markdown]
# **PRACTICA 3.1**

# %%
#Queremos listar 15 jugadores de la tabla Player de la base de datos de Fútbol Europeo.
#En la tabla de resultados quiero ver los campos ìd,player_name, birthday, height y weight.
#Todos se encuentran en la tabla Player

query= """SELECT id, player_name, birthday, height, weight FROM Player Limit 15;"""

Player = pd.read_sql(query, conn)
Player
# Out:
#     id         player_name             birthday  height  weight
# 0    1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1    2     Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# 2    3         Aaron Doran  1991-05-13 00:00:00  170.18     163
# 3    4       Aaron Galindo  1982-05-08 00:00:00  182.88     198
# 4    5        Aaron Hughes  1979-11-08 00:00:00  182.88     154
# 5    6          Aaron Hunt  1986-09-04 00:00:00  182.88     161
# 6    7          Aaron Kuhl  1996-01-30 00:00:00  172.72     146
# 7    8        Aaron Lennon  1987-04-16 00:00:00  165.10     139
# 8    9        Aaron Lennox  1993-02-19 00:00:00  190.50     181
# 9   10       Aaron Meijers  1987-10-28 00:00:00  175.26     170
# 10  11       Aaron Mokoena  1980-11-25 00:00:00  182.88     181
# 11  12          Aaron Mooy  1990-09-15 00:00:00  175.26     150
# 12  13      Aaron Muirhead  1990-08-30 00:00:00  187.96     168
# 13  14        Aaron Niguez  1989-04-26 00:00:00  170.18     143
# 14  15        Aaron Ramsey  1990-12-26 00:00:00  177.80     154

# %%
#Deben listar 25 equipos del fútbol europeo. La tabla de resultados deberá contener los campos
#id y team_long_name de la tabla Team de la base de datos de Fútbol Europeo.

query = """SELECT id, team_long_name FROM Team LIMIT 25;"""

team_long_name = pd.read_sql(query, conn)

team_long_name
# Out:
#       id        team_long_name
# 0      1              KRC Genk
# 1      2          Beerschot AC
# 2      3      SV Zulte-Waregem
# 3      4      Sporting Lokeren
# 4      5     KSV Cercle Brugge
# 5      6        RSC Anderlecht
# 6      7              KAA Gent
# 7      8             RAEC Mons
# 8      9         FCV Dender EH
# 9     10     Standard de Liège
# 10    11           KV Mechelen
# 11    12        Club Brugge KV
# 12    13         KSV Roeselare
# 13    14           KV Kortrijk
# 14    15                Tubize
# 15    16  Royal Excel Mouscron
# 16    17          KVC Westerlo
# 17    18    Sporting Charleroi
# 18   614     Sint-Truidense VV
# 19  1034             Lierse SK
# 20  1042             KAS Eupen
# 21  1513   Oud-Heverlee Leuven
# 22  2004      Waasland-Beveren
# 23  2476           KV Oostende
# 24  2510  Royal Excel Mouscron

# %% [markdown]
# ##4. Funciones agregativas/ Métricas
#
# Todas las métricas tienen que ser agregadas usando funciones. Las funciones agregativas más comunes son:
#
# SUM() | Sumatoria total de una columna tipo numérica.
#
# COUNT() | Devuelve la cantidad de filas.
#
# COUNT(DISTINCT) | Devuelve la cantidad de filas distintas o diferentes.
#
# AVG() | Promedia los valores de una columna tipo numérica.
#
# MIN() | Menor valor dentro de la columna especificada.
#
# MAX() | Mayor valor dentro de la columna especificada.
#
# La sintaxis de las métricas en la sentencia SELECT es así:

# %% [markdown]
# # **4.1 SUM()**
#
# SELECT SUM(column1), column2...
#
# FROM table_name

# %%
#Traer la suma de goles hechos por los equipos visitantes de la tabla Match

#Deben traer la suma de goles hechos por los equipos visitantes away_team_goal almacenados en la tabla Match
#de la base de datos de Fútbol Europeo. La tabla de resultados deberá mostrar únicamente el número con la suma de goles.

query = """SELECT SUM (away_team_goal) FROM Match;"""

away_team_goal = pd.read_sql(query, conn)
away_team_goal
# Out:
#    SUM (away_team_goal)
# 0                 30160

# %%
#Goles hechos por los equipos locales

query = """SELECT SUM (home_team_goal) FROM Match;"""

home_team_goal = pd.read_sql(query, conn)
home_team_goal
# Out:
#    SUM (home_team_goal)
# 0                 40127

# %%
#Suma de goles de equipos locales por liga

query = """SELECT SUM (home_team_goal), league_id FROM Match GROUP BY league_id;"""

home_team_goal = pd.read_sql(query, conn)
home_team_goal
# Out:
#     SUM (home_team_goal)  league_id
# 0                   2781          1
# 1                   4715       1729
# 2                   4265       4769
# 3                   3982       7809
# 4                   4528      10257
# 5                   4357      13274
# 6                   2678      15722
# 7                   2890      17642
# 8                   2607      19694
# 9                   4959      21518
# 10                  2365      24558

# %% [markdown]
# ##4.2 COUNT()
#
# Devuelve la cantidad de filas.
#
# SELECT COUNT(column1), column2...
#
# FROM table_name

# %%
query = """SELECT COUNT (player_name) FROM Player;"""

player_name = pd.read_sql(query, conn)
player_name
# Out:
#    COUNT (player_name)
# 0                11060

# %%
##Traer el número de etapas jugadas de la tabla Match
##Deben traer el número de etapas stage almacenados en la tabla Match de la base de datos de Fútbol Europeo.
#La tabla de resultados deberá mostrar únicamente el número con la cantidad de etapas diferentes.

query = """SELECT COUNT (home_team_goal) FROM Match;"""

home_team_goal = pd.read_sql(query, conn)
home_team_goal
# Out:
#    COUNT (home_team_goal)
# 0                   25979
